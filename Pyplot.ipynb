# %% [markdown]
# <a href="https://colab.research.google.com/github/avanegasp/gr-ficos_DS/blob/main/Pyplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
### Plot es el gráfico de líneas
plt.plot(x,y)

# %%
plt.plot(x,y,'xy')

# %%
plt.plot(x,y,'pink')

# %%
plt.plot(x,y,'rs-')

# %%
plt.plot(x,y,'bo')

# %%
plt.plot(x,y,'yD:')

# %%
plt.plot(x,y,'bo')

# %%
plt.hist(x,color='red')
plt.show()

# %%
plt.hist(x,y)
plt.show()

# %%
plt.pie(x)
plt.show()

# %%
plt.scatter(x,y, color='orange')
plt.show()

# %%
plt.boxplot(x)
plt.show()
