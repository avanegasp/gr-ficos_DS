# %% [markdown]
# <a href="https://colab.research.google.com/github/avanegasp/gr-ficos_DS/blob/main/Otras_gr%C3%A1ficas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.random.randint(1,50,100)

# %%
data
# Out:
# array([23, 24, 34, 10,  7, 30, 25, 28,  4, 18,  9, 35, 47, 12, 44, 29, 27,
#        45, 45,  7, 16, 10, 23, 40, 40, 44,  1, 47, 19, 26, 42, 39, 41, 34,
#        14, 26, 30, 21, 10, 33,  8, 43, 16, 28, 25, 38, 20, 44,  2, 48, 12,
#         6, 15, 42, 21,  1, 29, 14, 44, 15,  7, 34, 40, 47, 28,  7, 32,  4,
#        38, 38, 24, 43, 48, 34, 46, 40, 23, 24, 10, 18, 26, 27, 19, 14, 33,
#        26, 38,  9, 15,  2, 25, 48, 10, 34,  9,  1, 18, 29, 11, 47])

# %% [markdown]
# ## distibución es histograma

# %%
plt.hist(data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(data,bins=30,width=2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(data,bins=20,histtype='step')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## boxplot gráfico de cajas y bigotes

# %%
plt.boxplot(data)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(data,vert=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(data,vert=False, patch_artist=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(data,vert=False, patch_artist=True,notch=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data = np.append(data,200)
plt.boxplot(data,vert=False, patch_artist=True,notch=True,showfliers=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data = np.append(data,200)
plt.boxplot(data,vert=False, patch_artist=True,notch=True,showfliers=False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### gráficos de dispersión o sCATTER

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = (30 * np.random.rand(N)) **2
colors = np.random.rand(N)

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.scatter(x,y,s=area,c=colors)
plt.show()

# %%
plt.scatter(x,y,s=area,c=colors,marker='o',alpha=0.5)
plt.show()
